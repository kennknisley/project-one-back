# %%
import csv
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd

# %%
lines = list(range(0,1200))
magnitude = []
placename = []
time = []
updated = []
tz = []
urllog = []
details = []
felt = []
cdi = []
mmi = []
alert = []
status = []
tsunami = []
sig = []
net = []
code = []
ids = []
sources = []
types = []
nst = []
dmin = []
rms = []
gap = []
magtype = []
etype = []
title = []
ltype = []
coord = []

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&"
start = "starttime=1960-01-01"
end = "endtime=2020-03-02"
lat = "latitude=64.9311916"
lng = "longitude=-19.0211694"
radius = "maxradiuskm=500"

searchurl = f"{url}{start}&{end}&{lat}&{lng}&{radius}"
response = requests.get(searchurl).json()
print(searchurl)
#print(response)
# test = response["features"][0]
# print(test)

for row in lines:
    try:
        magnitude.append(response["features"][row]["properties"]["mag"])
        placename.append(response["features"][row]["properties"]["place"])
        time.append(response["features"][row]["properties"]["time"])
        updated.append(response["features"][row]["properties"]["updated"])
        tz.append(response["features"][row]["properties"]["tz"])
        urllog.append(response["features"][row]["properties"]["url"])
        details.append(response["features"][row]["properties"]["detail"])
        felt.append(response["features"][row]["properties"]["felt"])
        cdi.append(response["features"][row]["properties"]["cdi"])
        mmi.append(response["features"][row]["properties"]["mmi"])
        alert.append(response["features"][row]["properties"]["alert"])
        status.append(response["features"][row]["properties"]["status"])
        tsunami.append(response["features"][row]["properties"]["tsunami"])
        sig.append(response["features"][row]["properties"]["sig"])
        net.append(response["features"][row]["properties"]["net"])
        code.append(response["features"][row]["properties"]["code"])
        ids.append(response["features"][row]["properties"]["ids"])
        sources.append(response["features"][row]["properties"]["sources"])
        types.append(response["features"][row]["properties"]["types"])
        nst.append(response["features"][row]["properties"]["nst"])
        dmin.append(response["features"][row]["properties"]["dmin"])
        rms.append(response["features"][row]["properties"]["rms"])
        gap.append(response["features"][row]["properties"]["gap"])
        magtype.append(response["features"][row]["properties"]["magType"])
        etype.append(response["features"][row]["properties"]["type"])
        title.append(response["features"][row]["properties"]["title"])
        ltype.append(response["features"][row]["geometry"]["type"])
        coord.append(response["features"][row]["geometry"]["coordinates"])
    except:
        magnitude.append(0)
        placename.append(0)
        time.append(0)
        updated.append(0)
        tz.append(0)
        urllog.append(0)
        details.append(0)
        felt.append(0)
        cdi.append(0)
        mmi.append(0)
        alert.append(0)
        status.append(0)
        tsunami.append(0)
        sig.append(0)
        net.append(0)
        code.append(0)
        ids.append(0)
        sources.append(0)
        types.append(0)
        nst.append(0)
        dmin.append(0)
        rms.append(0)
        gap.append(0)
        magtype.append(0)
        etype.append(0)
        title.append(0)
        ltype.append(0)
        coord.append(0)
# Out:
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1960-01-01&endtime=2020-03-02&latitude=64.9311916&longitude=-19.0211694&maxradiuskm=500
# ['https://earthquake.usgs.gov/earthquakes/eventpage/us60007k5s', 'https://earthquake.usgs.gov/earthquakes/eventpage/us60007a2d', 'https://earthquake.usgs.gov/earthquakes/eventpage/us60007a28', 'https://earthquake.usgs.gov/earthquakes/eventpage/us600079aq', 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006uwl', 'https://earthquake.usgs.gov/earthquakes/eventpage/us700068u5', 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006bqj', 'https://earthquake.usgs.gov/earthquakes/eventpage/us60004uin', 'https://earthquake.usgs.gov/earthquakes/eventpage/us60004unb', 'https://earthquake.usgs.gov/earthquakes/eventpage/us70004hwe', 'https://earthquake.usgs.gov/earthquakes/eventpage/us60004584', 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000457r', 'https://earthquake.usgs.gov/earthquakes/eventpage/us70003xds', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000j8it', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000j8j8', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000jcge', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000j8ed', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000jced', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000j8ds', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jm6n', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000iz6z', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000iygs', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000hx0w', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000hsvf', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000hfw6', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000hi7p', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000genz', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000gaiq', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000g6wa', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000erk1', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000e7bm', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000d7b5', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d9n2', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d4l9', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d4l6', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d4k6', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d4k4', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d9n3', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d70q', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000crfy', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000btik', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000bjct', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000axc8', 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000axbq', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000at5l', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000at6b', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ahc4', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ac6d', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000a3ln', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000a1jq', 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000a37i', 'https://earthquake.usgs.gov/earthquakes/eventpage/us100097mh', 'https://earthquake.usgs.gov/earthquakes/eventpage/us100096e1', 'https://earthquake.usgs.gov/earthquakes/eventpage/us10008vrn', 'https://earthquake.usgs.gov/earthquakes/eventpage/us10008tx3', 'https://earthquake.usgs.gov/earthquakes/eventpage/us10008icd', 'https://earthquake.usgs.gov/earthquakes/eventpage/us20008v2m', 'https://earthquake.usgs.gov/earthquakes/eventpage/us20008uqs', 'https://earthquake.usgs.gov/earthquakes/eventpage/us20008uql', 'https://earthquake.usgs.gov/earthquakes/eventpage/us20008uqg', 'https://earthquake.usgs.gov/earthquakes/eventpage/us20008uqd', 'https://earthquake.usgs.gov/earthquakes/eventpage/us20008iys', 'https://earthquake.usgs.gov/ea ...

# %%
earthquakedf = pd.DataFrame(lines)
earthquakedf
# Out:
#          0
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 1195  1195
# 1196  1196
# 1197  1197
# 1198  1198
# 1199  1199
#
# [1200 rows x 1 columns]

# %%
earthquakedf["Magnitude"] = magnitude
earthquakedf["Name"] = placename
earthquakedf["Time"] = time
earthquakedf["Last Updated"] = updated
earthquakedf["TZ"] = tz
earthquakedf["URL"] = urllog
earthquakedf["Details"] = details
earthquakedf["Felt"] = felt
earthquakedf["CDI"] = cdi
earthquakedf["MMI"] = mmi
earthquakedf["Alert"] = alert
earthquakedf["Status"] = status
earthquakedf["Tsunami"] = tsunami
earthquakedf["SIG"] = sig
earthquakedf["Net"] = net
earthquakedf["Code"] = code
earthquakedf["IDS"] = ids
earthquakedf["Sources"] = sources
earthquakedf["Types"] = types
earthquakedf["NST"] = nst
earthquakedf["DMIN"] = dmin
earthquakedf["RMS"] = rms
earthquakedf["GAP"] = gap
earthquakedf["MagType"] = magtype
earthquakedf["Etype"] = etype
earthquakedf["Title"] = title
earthquakedf["Location Type"] = ltype
earthquakedf["Coordinates"] = coord

# %%
earthquakedf = earthquakedf[earthquakedf.Magnitude != 0]
earthquakedf.to_csv("earthquakedata.csv",index=False)
earthquakedf
# Out:
#          0  Magnitude                            Name           Time  \
# 0        0        4.5  85km WSW of Grindavik, Iceland  1579362596645
# 1        1        4.5  89km WSW of Grindavik, Iceland  1579357058501
# 2        2        4.3   67km SW of Sandgerdi, Iceland  1579356460299
# 3        3        4.2    114km S of Akureyri, Iceland  1578200193041
# 4        4        4.9  116km SSE of Akureyri, Iceland  1578198773421
# ...    ...        ...                             ...            ...
# 1178  1178        4.5                  Iceland region   102502273000
# 1179  1179        4.3                  Iceland region   102502131700
# 1180  1180        6.0                  Iceland region   -33833745000
# 1181  1181        5.8                  Iceland region  -196092029000
# 1182  1182        6.9                  Iceland region  -213493450000
#
#        Last Updated     TZ                                                URL  \
# 0     1580753405040 -120.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1     1581279751879 -120.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 2     1581279566040 -120.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 3     1580451360040    0.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 4     1581551787040    0.0  https://earthquake.usgs.gov/earthquakes/eventp...
# ...             ...    ...                                                ...
# 1178  1415316070678    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1179  1415316070676    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1180  1577488921027    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1181  1431543177000    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1182  1577556340034    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                 Details  Felt  CDI  ...  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  3.4  ...
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# ...                                                 ...   ...  ...  ...
# 1178  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 1179  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 1180  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 1181  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
# 1182  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  ...
#
#                                            Types NST   DMIN   RMS    GAP  \
# 0                   ,geoserve,origin,phase-data, NaN  1.699  0.76   66.0
# 1              ,dyfi,geoserve,origin,phase-data, NaN  1.728  0.69  128.0
# 2                   ,geoserve,origin,phase-data, NaN  1.537  1.25  153.0
# 3                   ,geoserve,origin,phase-data, NaN  1.495  1.03  115.0
# 4     ,geoserve,moment-tensor,origin,phase-data, NaN  1.618  0.87   83.0
# ...                                          ...  ..    ...   ...    ...
# 1178                                    ,origin, NaN    NaN   NaN    NaN
# 1179                                    ,origin, NaN    NaN   NaN    NaN
# 1180            ,origin,shakemap,trump-shakemap, NaN    NaN   NaN    NaN
# 1181                                    ,origin, NaN    NaN   NaN    NaN
# 1182            ,origin,shakemap,trump-shakemap, NaN    NaN   NaN    NaN
#
#      MagType       Etype                                   Title  \
# 0         mb  earthquake  M 4.5 - 85km WSW of Grindavik, Iceland
# 1         mb  earthquake  M 4.5 - 89km WSW of Grindavik, Iceland
# 2         mb  earthquake   M 4.3 - 67km SW of Sandgerdi, Iceland
# 3         mb  earthquake    M 4.2 - 114km S of Akureyri, Iceland
# 4        mww  earthquake  M 4.9 - 116km SSE of Akureyri, Iceland
# ...      ...         ...                                     ...
# 1178      mb  earthquake                  M 4.5 - Iceland region
# 1179      mb  earthquake                  M 4.3 - Iceland region
# 1180      mw  earthquake                  M 6.0 - Iceland region
# 1181      mw  earthquake                  M 5.8 - Iceland region
# 1182      mw  earthquake                  M 6.9 - Iceland region
#
#      Location Type              Coordinates
# 0            Point  [-24.0255, 63.5326, 10]
# 1            Point  [-24.1042, 63.5254, 10]
# 2            Point   [-23.7586, 63.642, 10]
# 3            Point  [-17.8506, 64.6639, 10]
# 4            Point  [-17.5641, 64.6591, 10]
# ...            ...                      ...
# 1178         Point    [-18.556, 67.759, 33]
# 1179         Point    [-18.904, 68.166, 33]
# 1180         Point    [-21.954, 63.929, 10]
# 1181         Point    [-18.526, 67.303, 15]
# 1182         Point    [-19.824, 66.218, 10]
#
# [1159 rows x 29 columns]
