# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
main=pd.read_csv('IcelandData.csv', header=4)
main.drop(['Country Name','Country Code','Indicator Code'],inplace=True, axis=1)
main=main.iloc[[15,60,146, 396,392,513,645,813,821,824,829,833]]
main.set_index('Indicator Name', inplace=True)
main.to_csv('condensedata.csv', index=True, header=True)
main=main.transpose()
main
# Out:
# Indicator Name  GDP per person employed (constant 2011 PPP $)  \
# 1960                                                      NaN
# 1961                                                      NaN
# 1962                                                      NaN
# 1963                                                      NaN
# 1964                                                      NaN
# 1965                                                      NaN
# 1966                                                      NaN
# 1967                                                      NaN
# 1968                                                      NaN
# 1969                                                      NaN
# 1970                                                      NaN
# 1971                                                      NaN
# 1972                                                      NaN
# 1973                                                      NaN
# ...

# %%
#Plot GDP per person emoloyed by year
# GDP per person employed is gross domestic product (GDP) divided by total employment 
#in the economy. Purchasing power parity (PPP) GDP is GDP converted to 2011 constant 
#international dollars using PPP rates.
GDPperson=main.iloc[:,0]
GDPperson=GDPperson.dropna(how='any')
x_value1=np.arange(1991,2020,1)
plt.plot(x_value1, GDPperson, color='red', marker='*')
plt.title('GDP per person Employed')
plt.xlabel('Year')
plt.ylabel('Normalized to International dollars')
plt.grid(color='grey', axis='both')
plt.show()

# %%
#plot trade (% of GDP)
#The trade-to-GDP ratio is an indicator of the relative importance of international trade 
#in the economy of a country. It is calculated by dividing the aggregate value of imports 
#and exports over a period by the gross domestic product for the same period. Although called 
#a ratio, it is usually expressed as a percentage.
TradeGDP=main.iloc[:,1]
TradeGDP=TradeGDP.dropna(how='any')
x_value2=np.arange(1970,2019,1)
plt.plot(x_value2, TradeGDP, color='green', marker='d')
plt.title('Trade Percent of GDP')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.grid(axis='both',color='grey')
plt.show()

# %%
#plot manufactures exports (% of merchandise export)
#The share of manufactures exports in the merchandise exports of the country, expressed in percentage.
#Manufactures comprise commodities in SITC sections 5 (chemicals), 6 (basic manufactures), 
#7 (machinery and transport equipment), and 8 (miscellaneous manufactured goods), excluding
#division 68 (non-ferrous metals).
ManuExp=main.iloc[:,2]
ManuExp=ManuExp.dropna(how='any')
x_value3=np.arange(1962,2019,1)
plt.plot(x_value3, ManuExp, color='blue', marker='+')
plt.grid(color='grey',axis='both')
plt.title('Manufactures Export (% of merchandise export)')
plt.ylabel('Percent')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
lenborrow = main.iloc[:,6]
lenborrow = lenborrow.dropna(how='any')
x_value3=np.arange(1972,2019,1)
plt.plot(x_value3, lenborrow, color='red', marker="*")
plt.grid(color='grey', axis='both')
plt.title('Net lending (+) / net borrowing (-) (% of GDP)')
plt.ylabel('Percent')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
domsavings = main.iloc[:,7]
domsavings = domsavings.dropna(how='any')
x_value3=np.arange(1970,2019,1)
plt.plot(x_value3, domsavings, color='red', marker="*")
plt.grid(color='grey', axis='both')
plt.title('Gross domestic savings (% of GDP)')
plt.ylabel('Percent')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
capitagrowth = main.iloc[:,8]
capitagrowth = capitagrowth.dropna(how='any')
x_value3=np.arange(1961,2019,1)
plt.plot(x_value3, capitagrowth, color='red', marker="*")
plt.grid(color='grey', axis='both')
plt.title('GDP per capita growth (annual %)')
plt.ylabel('Percent')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')
