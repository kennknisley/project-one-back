# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
main=pd.read_csv('IcelandData.csv', header=4)
main.drop(['Country Name','Country Code','Indicator Code'],inplace=True, axis=1)
main=main.iloc[[15,60,146, 396,392,513,645,813,821,824,829,833]]
main.set_index('Indicator Name', inplace=True)
main.transpose()
main.to_csv('condensedata.csv', index=True, header=True)
main
# Out:
#                                                          1960          1961  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)             NaN           NaN
# Trade (% of GDP)                                          NaN           NaN
# Manufactures exports (% of merchandise exports)           NaN           NaN
# Taxes on international trade (% of revenue)               NaN           NaN
# Tax revenue (% of GDP)                                    NaN           NaN
# Surface area (sq. km)                                     NaN  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)            NaN           NaN
# Gross domestic savings (% of GDP)                         NaN           NaN
# GDP per capita growth (annual %)                          NaN -2.012883e+00
# GDP per capita (current US$)                     1.414982e+03  1.418126e+03
# GDP growth (annual %)                                     NaN -8.466195e-02
# GDP (current US$)                                2.484341e+08  2.538857e+08
#
#                                                          1962          1963  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)             NaN           NaN
# Trade (% of GDP)                                          NaN           NaN
# Manufactures exports (% of merchandise exports)  1.210346e+00  1.710342e+00
# Taxes on international trade (% of revenue)               NaN           NaN
# Tax revenue (% of GDP)                                    NaN           NaN
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)            NaN           NaN
# Gross domestic savings (% of GDP)                         NaN           NaN
# GDP per capita growth (annual %)                 6.324752e+00  8.337936e+00
# GDP per capita (current US$)                     1.562231e+03  1.831706e+03
# GDP growth (annual %)                            8.313713e+00  1.028338e+01
# GDP (current US$)                                2.849165e+08  3.400617e+08
#
#                                                          1964          1965  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)             NaN           NaN
# Trade (% of GDP)                                          NaN           NaN
# Manufactures exports (% of merchandise exports)  1.857268e+00  1.663195e+00
# Taxes on international trade (% of revenue)               NaN           NaN
# Tax revenue (% of GDP)                                    NaN           NaN
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)            NaN           NaN
# Gross domestic savings (% of GDP)                         NaN           NaN
# GDP per capita growth (annual %)                 7.979745e+00  5.527347e+00
# GDP per capita (current US$)                     2.297921e+03  2.723521e+03
# GDP growth (annual %)                            9.916544e+00  7.371729e+00
# GDP (current US$)                                4.342679e+08  5.236949e+08
#
#                                                          1966          1967  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)             NaN           NaN
# Trade (% of GDP)                                          NaN           NaN
# Manufactures exports (% of merchandise exports)  3.230977e+00  3.519278e+00
# Taxes on international trade (% of revenue)               NaN           NaN
# Tax revenue (% of GDP)                                    NaN           NaN
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)            NaN           NaN
# Gross domestic savings (% of GDP)                         NaN           NaN
# GDP per capita growth (annual %)                 6.910046e+00 -2.847474e+00
# GDP per capita (current US$)                     3.215694e+03  3.125649e+03
# GDP growth (annual %)                            8.735933e+00 -1.267262e+00
# GDP (current US$)                                6.288933e+08  6.212260e+08
#
#                                                          1968          1969  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)             NaN           NaN
# Trade (% of GDP)                                          NaN           NaN
# Manufactures exports (% of merchandise exports)  2.505313e+00  4.352084e+00
# Taxes on international trade (% of revenue)               NaN           NaN
# Tax revenue (% of GDP)                                    NaN           NaN
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)            NaN           NaN
# Gross domestic savings (% of GDP)                         NaN           NaN
# GDP per capita growth (annual %)                -6.758929e+00  1.427705e+00
# GDP per capita (current US$)                     2.354480e+03  2.039196e+03
# GDP growth (annual %)                           -5.474906e+00  2.374588e+00
# GDP (current US$)                                4.743995e+08  4.147093e+08
#
#                                                  ...          2010  \
# Indicator Name                                   ...
# GDP per person employed (constant 2011 PPP $)    ...  7.056869e+04
# Trade (% of GDP)                                 ...  9.409104e+01
# Manufactures exports (% of merchandise exports)  ...  1.462571e+01
# Taxes on international trade (% of revenue)      ...  1.274000e+00
# Tax revenue (% of GDP)                           ...  2.009200e+01
# Surface area (sq. km)                            ...  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)   ... -8.469155e+00
# Gross domestic savings (% of GDP)                ...  2.378162e+01
# GDP per capita growth (annual %)                 ... -3.296819e+00
# GDP per capita (current US$)                     ...  4.302492e+04
# GDP growth (annual %)                            ... -3.435878e+00
# GDP (current US$)                                ...  1.368369e+10
#
#                                                          2011          2012  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)    7.136673e+04  7.092070e+04
# Trade (% of GDP)                                 1.018191e+02  1.042675e+02
# Manufactures exports (% of merchandise exports)  1.400389e+01  1.427917e+01
# Taxes on international trade (% of revenue)      1.479897e+00  1.422470e+00
# Tax revenue (% of GDP)                           2.059430e+01  2.143934e+01
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)  -4.887932e+00 -3.146524e+00
# Gross domestic savings (% of GDP)                2.318828e+01  2.184283e+01
# GDP per capita growth (annual %)                 1.570878e+00  7.588685e-01
# GDP per capita (current US$)                     4.751688e+04  4.591002e+04
# GDP growth (annual %)                            1.881619e+00  1.296436e+00
# GDP (current US$)                                1.515855e+10  1.472408e+10
#
#                                                          2013          2014  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)    7.230939e+04  7.198122e+04
# Trade (% of GDP)                                 9.930630e+01  9.699365e+01
# Manufactures exports (% of merchandise exports)  1.207738e+01  1.383740e+01
# Taxes on international trade (% of revenue)      9.953256e-01  8.882236e-01
# Tax revenue (% of GDP)                           2.197134e+01  2.464308e+01
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)  -1.212993e+00  7.156380e-01
# Gross domestic savings (% of GDP)                2.307970e+01  2.334113e+01
# GDP per capita growth (annual %)                 3.153507e+00  9.509329e-01
# GDP per capita (current US$)                     4.952224e+04  5.424205e+04
# GDP growth (annual %)                            4.133851e+00  2.080287e+00
# GDP (current US$)                                1.603352e+10  1.775809e+10
#
#                                                          2015          2016  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)    7.317514e+04  7.645984e+04
# Trade (% of GDP)                                 9.672570e+01  8.861130e+01
# Manufactures exports (% of merchandise exports)  1.172681e+01  1.314353e+01
# Taxes on international trade (% of revenue)      7.246741e-01  4.444491e-01
# Tax revenue (% of GDP)                           2.291582e+01  3.775291e+01
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)  -2.111226e-01  1.224615e+01
# Gross domestic savings (% of GDP)                2.649449e+01  2.781532e+01
# GDP per capita growth (annual %)                 3.385019e+00  5.871644e+00
# GDP per capita (current US$)                     5.242860e+04  6.175795e+04
# GDP growth (annual %)                            4.467861e+00  7.351475e+00
# GDP (current US$)                                1.734417e+10  2.071602e+10
#
#                                                          2017          2018  \
# Indicator Name
# GDP per person employed (constant 2011 PPP $)    7.951162e+04  8.206779e+04
# Trade (% of GDP)                                 8.812613e+01  9.134944e+01
# Manufactures exports (% of merchandise exports)  1.301261e+01  1.098734e+01
# Taxes on international trade (% of revenue)      4.624714e-01  4.698049e-01
# Tax revenue (% of GDP)                           2.415650e+01  2.331788e+01
# Surface area (sq. km)                            1.030000e+05  1.030000e+05
# Net lending (+) / net borrowing (-) (% of GDP)   1.798275e+00 -6.779573e-01
# Gross domestic savings (% of GDP)                2.619295e+01  2.568761e+01
# GDP per capita growth (annual %)                 2.178765e+00  1.601308e+00
# GDP per capita (current US$)                     7.131477e+04  7.319112e+04
# GDP growth (annual %)                            4.603781e+00  4.611476e+00
# GDP (current US$)                                2.448949e+10  2.587848e+10
#
#                                                         2019
# Indicator Name
# GDP per person employed (constant 2011 PPP $)    84533.72656
# Trade (% of GDP)                                         NaN
# Manufactures exports (% of merchandise exports)          NaN
# Taxes on international trade (% of revenue)              NaN
# Tax revenue (% of GDP)                                   NaN
# Surface area (sq. km)                                    NaN
# Net lending (+) / net borrowing (-) (% of GDP)           NaN
# Gross domestic savings (% of GDP)                        NaN
# GDP per capita growth (annual %)                         NaN
# GDP per capita (current US$)                             NaN
# GDP growth (annual %)                                    NaN
# GDP (current US$)                                        NaN
#
# [12 rows x 60 columns]

# %%
GDPperson=main.iloc[0]
GDPperson=GDPperson.dropna(how='any')
x_value1=np.arange(1991,2020,1)
plt.plot(x_value1, GDPperson)

# %%
TradeGDP=main.iloc[1]
TradeGDP=TradeGDP.dropna(how='any')
x_value2=np.arange(1970,2019,1)
plt.plot(x_value2, TradeGDP)

# %%
ManuExp=main.iloc[2]
ManuExp=ManuExp.dropna(how='any')
x_value3=np.arange(1962,2019,1)
plt.plot(x_value3, ManuExp)
