# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# %%
angies_df = pd.read_csv("angies_data.csv")
angies_df.head()
# Out:
#    Year  Netlending/Netborrowing  Grossdomesticsavings  GDPpercapitagrowth
# 0  1960                      NaN                   NaN                 NaN
# 1  1961                      NaN                   NaN           -2.012883
# 2  1962                      NaN                   NaN            6.324752
# 3  1963                      NaN                   NaN            8.337936
# 4  1964                      NaN                   NaN            7.979745

# %%
netlending_df = angies_df[['Year', 'Netlending/Netborrowing' ]]
netlending_df
# Out:
#     Year  Netlending/Netborrowing
# 0   1960                      NaN
# 1   1961                      NaN
# 2   1962                      NaN
# 3   1963                      NaN
# 4   1964                      NaN
# 5   1965                      NaN
# 6   1966                      NaN
# 7   1967                      NaN
# 8   1968                      NaN
# 9   1969                      NaN
# 10  1970                      NaN
# 11  1971                      NaN
# 12  1972                 0.619786
# 13  1973                -0.057578
# 14  1974                -2.241696
# 15  1975                -2.304193
# 16  1976                 1.040751
# 17  1977                -0.329646
# 18  1978                -0.011730
# 19  1979                -0.134970
# 20  1980                 0.466545
# 21  1981                 0.955602
# 22  1982                 0.801690
# 23  1983                -2.297390
# 24  1984                 0.967211
# 25  1985                -1.849939
# ...

# %%
netlending_df_clean = netlending_df.dropna()
netlending_df_clean
# Out:
#     Year  Netlending/Netborrowing
# 12  1972                 0.619786
# 13  1973                -0.057578
# 14  1974                -2.241696
# 15  1975                -2.304193
# 16  1976                 1.040751
# 17  1977                -0.329646
# 18  1978                -0.011730
# 19  1979                -0.134970
# 20  1980                 0.466545
# 21  1981                 0.955602
# 22  1982                 0.801690
# 23  1983                -2.297390
# 24  1984                 0.967211
# 25  1985                -1.849939
# 26  1986                -3.922995
# 27  1987                -2.162592
# 28  1988                -3.386721
# 29  1989                -3.347992
# 30  1990                -2.567102
# 31  1991                -3.682495
# 32  1992                -2.598985
# 33  1993                -3.022840
# 34  1994                -2.848236
# 35  1995                -2.407392
# 36  1996                -1.139659
# 37  1997                 0.411088
# ...

# %%
#Plot the Net Lending vs. Time

x_values = netlending_df_clean["Year"]
y_values = netlending_df_clean["Netlending/Netborrowing"]
plt.plot(x_values, y_values)
plt.title("Net Lending vs. Time")
plt.xlabel("Time")
plt.ylabel("Net Lending/Net Borrowing")
# Out:
# Text(0, 0.5, 'Net Lending/Net Borrowing')

# %%
scater_plot() for:
    y_values = angies_df["Net lending (+) / net borrowing (-) (% of GDP)"]

# %%
domesticsavings_df = angies_df[['Year', 'Grossdomesticsavings']]
domesticsavings_df = domesticsavings_df.dropna()
domesticsavings_df
# Out:
#     Year  Grossdomesticsavings
# 10  1970             28.641094
# 11  1971             28.548096
# 12  1972             28.263031
# 13  1973             31.797054
# 14  1974             27.900250
# 15  1975             28.403230
# 16  1976             30.639817
# 17  1977             30.671756
# 18  1978             29.342970
# 19  1979             27.818265
# 20  1980             28.578978
# 21  1981             26.877117
# 22  1982             24.920822
# 23  1983             24.782640
# 24  1984             24.730060
# 25  1985             22.587728
# 26  1986             23.901341
# 27  1987             21.333798
# 28  1988             21.604126
# 29  1989             22.695806
# 30  1990             21.936236
# 31  1991             20.478616
# 32  1992             19.721751
# 33  1993             21.727644
# 34  1994             22.788191
# 35  1995             21.608858
# 36  1996             21.216638
# 37  1997             22.201430
# 38  1998             21.537277
# ...
