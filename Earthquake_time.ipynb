# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import datetime

# %%
eq_data = pd.read_csv("earthquakedata.csv")
eq_data.head()
# Out:
#    0  Magnitude                            Name           Time   Last Updated  \
# 0  0        4.5  85km WSW of Grindavik, Iceland  1579362596645  1580753405040
# 1  1        4.5  89km WSW of Grindavik, Iceland  1579357058501  1581279751879
# 2  2        4.3   67km SW of Sandgerdi, Iceland  1579356460299  1581279566040
# 3  3        4.2    114km S of Akureyri, Iceland  1578200193041  1580451360040
# 4  4        4.9  116km SSE of Akureyri, Iceland  1578198773421  1581551787040
#
#       TZ                                                URL  \
# 0 -120.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1 -120.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 2 -120.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 3    0.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 4    0.0  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                              Details  Felt  CDI  ...  \
# ...
